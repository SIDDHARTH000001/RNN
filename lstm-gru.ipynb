# %%
import json
import zipfile
import os
import random
from torch.optim.lr_scheduler import StepLR

# %%
# def read_json_from_zip(zip_path, json_filename):
#     with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#         with zip_ref.open(json_filename) as json_file:
#             data = json_file.read().decode('utf-8')
#             json_data = json.loads(data)
#             return json_data
        
def read_json_from_folder(folder_path, json_filename):
    file_path = os.path.join(folder_path, json_filename)
    with open(file_path, 'r', encoding='utf-8') as json_file:
        json_data = json.load(json_file)
    return json_data

# %%
recipe = read_json_from_folder("/kaggle/input/recipe","full_format_recipes.json")

# %%
filtered_data = [
        'Recipe for ' + x['title']+ ' | ' + ' '.join(x['directions']) for x in recipe
                                                                            if 'title' in x
                                                                            and x['title'] is not None
                                                                            and 'directions' in x
                                                                            and x['directions'] is not None
]

# %%
import re
import string

def pad_punctuation(s):
    s = re.sub(f"([{string.punctuation}])", r' \1 ', s)
    s = re.sub(' +', ' ', s)
    return s



import torch
from torch.utils.data import Dataset, DataLoader
from collections import Counter

class TextDataset(Dataset):
    def __init__(self, texts, vocab, seq_length):
        self.texts = texts
        self._dict = vocab
        self.vocab = lambda x:vocab.get(x)
        self.seq_length = seq_length
        self.revocab = {value: key for key, value in vocab.items()}
        self.token2word = lambda x :self.revocab.get(x)

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        tokens = self.texts[idx].split()
        token_ids = [self.vocab(token) if token in self._dict else self.vocab('<unk>') for token in tokens]
        token_ids = token_ids[:self.seq_length] + [self.vocab('<pad>')] * max(0, self.seq_length - len(token_ids))
        return torch.tensor(token_ids)

def build_vocab(texts, max_tokens=10000):
    counter = Counter()
    for text in texts:
        counter.update(text.split())
    sorted_vocab = sorted(counter.items(), key=lambda x: x[1], reverse=True)[:max_tokens-2]
    vocab_list = ['<pad>', '<unk>'] + [item[0] for item in sorted_vocab]
    vocab_dict = {word: idx for idx, word in enumerate(vocab_list)}
    return vocab_dict

# %%
text_data = [pad_punctuation(x) for x in filtered_data]
vocab = build_vocab(text_data, max_tokens=10000)
dataset = TextDataset(text_data, vocab, seq_length=200)
# data_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
from torch.nn.utils.rnn import pad_sequence

def prepare_inputs(batch):
    x = batch[:, :-1]
    y = batch[:, 1:]
    return x, y

class MyCollate:
    def __call__(self, batch):
        batch = pad_sequence(batch, batch_first=True, padding_value=vocab.get('<pad>'))
        return prepare_inputs(batch)

collate_fn = MyCollate()
data_loader = DataLoader(dataset, batch_size=32, shuffle=True, collate_fn=collate_fn)

# %%
for x, y in data_loader:
    print("Input (x):", x)
    print("Target (y):", y)
    print("x shape:", x.shape)
    print("y shape:", y.shape)
    break
# Out:
# Input (x): tensor([[  26,   16, 4629,  ..., 1012,    8,   11],
#         [  26,   16, 1148,  ...,    0,    0,    0],
#         [  26,   16, 1582,  ...,    0,    0,    0],
#         ...,
#         [  26,   16, 9098,  ...,    0,    0,    0],
#         [  26,   16, 1189,  ...,    0,    0,    0],
#         [  26,   16,    1,  ...,  723,   60, 5730]])
# Target (y): tensor([[  16, 4629,   13,  ...,    8,   11,   23],
#         [  16, 1148, 2470,  ...,    0,    0,    0],
#         [  16, 1582,    4,  ...,    0,    0,    0],
#         ...,
#         [  16, 9098,  897,  ...,    0,    0,    0],
#         [  16, 1189,  803,  ...,    0,    0,    0],
#         [  16,    1, 9169,  ...,   60, 5730,    5]])
# x shape: torch.Size([32, 199])
# y shape: torch.Size([32, 199])

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class LSTMModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super(LSTMModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
#         self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.lstm = nn.GRU(embedding_dim, hidden_dim, batch_first=True,bidirectional=True)
        self.dropout = nn.Dropout(.2)
        self.fc = nn.Linear(hidden_dim * 2, output_dim)
        self.softmax = nn.Softmax(dim=-1)
        
        
    

    def _initialize_weights(self):
        # Glorot initialization for embedding and fully connected layer
        nn.init.xavier_uniform_(self.embedding.weight)
        nn.init.xavier_uniform_(self.fc.weight)
        if self.fc.bias is not None:
            nn.init.zeros_(self.fc.bias)

        # Glorot initialization for LSTM input-hidden and hidden-hidden weights
        for name, param in self.lstm.named_parameters():
            if 'weight_ih' in name or 'weight_hh' in name:
                nn.init.xavier_uniform_(param.data)
            elif 'bias' in name:
                # Initialize biases to zero, except for forget gate bias
                param.data.fill_(0)
                if 'bias_ih' in name:
                    n = param.size(0)
                    param.data[n//4:n//2].fill_(1)  # Set forget gate bias to 1
                
    def forward(self, x):
        x = self.embedding(x)
        x,_ = self.lstm(x)
        x = self.dropout(x)
        x = self.fc(x)
        x = self.softmax(x)
        return x

# %%
vocab_size = 10000
embedding_dim = 150
hidden_dim = 128
output_dim = 10000

model = LSTMModel(vocab_size, embedding_dim, hidden_dim, output_dim)
model._initialize_weights()

# %%
# Loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=.03)
model.to("cuda")
scheduler = StepLR(optimizer, step_size=5, gamma=0.1)

# %%
epochs = 25
loss_list = []
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for batch in data_loader:
        inputs, targets = batch
        inputs, targets = inputs.to("cuda"), targets.to("cuda")
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_fn(outputs.view(-1, outputs.shape[-1]), targets.reshape(-1))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    average_loss = total_loss / len(data_loader)
    loss_list.append(average_loss)
    print(f"Epoch {epoch+1}/{epochs}, Loss: {average_loss:.4f}")
    scheduler.step()
# Out:
# Epoch 1/25, Loss: 8.9445
# Epoch 2/25, Loss: 8.9393

# %%
import torch
import torch.nn as nn
import numpy as np

class TextGenerator:
    def __init__(self, model, index_to_word, top_k=10):
        self.model = model
        self.index_to_word = index_to_word
        self.word_to_index = {word: index for index, word in enumerate(index_to_word)}
        self.top_k = top_k

    def sample_from(self, probs, temperature):
        probs = probs.cpu().numpy()  # Convert to numpy array
        probs = probs ** (1 / temperature)
        probs = probs / np.sum(probs)
        return np.random.choice(len(probs), p=probs), probs

    def generate(self, start_prompt, max_tokens, temperature):
        start_tokens = [self.word_to_index.get(x, 1) for x in start_prompt.split()]
        sample_token = None
        info = []

        self.model.eval()  # Set the model to evaluation mode

        with torch.no_grad():
            while len(start_tokens) < max_tokens and sample_token != 0:
                x = torch.tensor([start_tokens]).long()
                if torch.cuda.is_available():
                    x = x.cuda()

                y = self.model(x)
                y = y[0, -1, :]  # Get the last token's predictions
                y = nn.functional.softmax(y, dim=-1)

                sample_token, probs = self.sample_from(y, temperature)
                info.append({'prompt': start_prompt, 'word_probs': probs})
                start_tokens.append(sample_token)
                start_prompt = start_prompt + ' ' + self.index_to_word.get(sample_token)

        print(f"\ngenerated text:\n{start_prompt}\n")
        return info

    def on_epoch_end(self, epoch, logs=None):
        self.generate("recipe for", max_tokens=100, temperature=1.0)

# %%
index_to_word = dataset.revocab

generator = TextGenerator(model, index_to_word)

# %%
generator.generate("recipe for grilled apple", max_tokens=100, temperature=0.3)

# for epoch in range(5):
#     generator.on_epoch_end(epoch)
# Out:
# generated text:
# recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal lacquered concentrate wingtips container slice Rest freekeh adequate Fontina chunks—to syrups Shank overblend Wilt
# [{'prompt': 'recipe for grilled apple',
#   'word_probs': array([9.973049e-05, 9.973049e-05, 2.795009e-03, ..., 9.973049e-05,
#          9.973049e-05, 9.973049e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif',
#   'word_probs': array([9.9732155e-05, 9.9732155e-05, 2.7773038e-03, ..., 9.9732155e-05,
#          9.9732155e-05, 9.9732155e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish',
#   'word_probs': array([1.2028263e-03, 9.9877223e-05, 1.0638614e-04, ..., 9.9877223e-05,
#          9.9877223e-05, 9.9877223e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North',
#   'word_probs': array([1.0025557e-04, 9.9731798e-05, 2.7810370e-03, ..., 9.9731798e-05,
#          9.9731798e-05, 9.9731798e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane',
#   'word_probs': array([9.9730416e-05, 9.9730416e-05, 2.7953829e-03, ..., 9.9730416e-05,
#          9.9730416e-05, 9.9730416e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada',
#   'word_probs': array([9.9730467e-05, 9.9730445e-05, 2.7953582e-03, ..., 9.9730445e-05,
#          9.9730445e-05, 9.9730445e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi',
#   'word_probs': array([9.9741846e-05, 9.9741846e-05, 1.0416834e-04, ..., 9.9741846e-05,
#          9.9741846e-05, 9.9741846e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp',
#   'word_probs': array([9.9910627e-05, 9.9910627e-05, 6.8591215e-04, ..., 9.9910627e-05,
#          9.9910627e-05, 9.9910627e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet',
#   'word_probs': array([9.9847290e-05, 9.9847290e-05, 1.8076591e-04, ..., 9.9847290e-05,
#          9.9847290e-05, 9.9847290e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly',
#   'word_probs': array([9.9853758e-05, 9.9853758e-05, 1.1545082e-04, ..., 9.9853758e-05,
#          9.9853758e-05, 9.9853758e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding',
#   'word_probs': array([9.976007e-05, 9.976007e-05, 9.976010e-05, ..., 9.976007e-05,
#          9.976007e-05, 9.976007e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama',
#   'word_probs': array([9.9893747e-05, 9.9893747e-05, 2.6255214e-04, ..., 9.9893747e-05,
#          9.9893747e-05, 9.9893747e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates',
#   'word_probs': array([9.9731027e-05, 9.9731027e-05, 9.9961835e-05, ..., 9.9731027e-05,
#          9.9731027e-05, 9.9731027e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects',
#   'word_probs': array([9.9744539e-05, 9.9730532e-05, 2.7945165e-03, ..., 9.9730532e-05,
#          9.9730532e-05, 9.9730532e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs',
#   'word_probs': array([9.9751116e-05, 9.9732635e-05, 1.0053943e-04, ..., 9.9732635e-05,
#          9.9732635e-05, 9.9732635e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep',
#   'word_probs': array([9.980072e-05, 9.980072e-05, 9.981564e-05, ..., 9.980072e-05,
#          9.980072e-05, 9.980072e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery',
#   'word_probs': array([9.973051e-05, 9.973046e-05, 9.974236e-05, ..., 9.973046e-05,
#          9.973046e-05, 9.973046e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente',
#   'word_probs': array([9.9730831e-05, 9.9730831e-05, 2.7910874e-03, ..., 9.9730831e-05,
#          9.9730831e-05, 9.9730831e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub',
#   'word_probs': array([9.9730423e-05, 9.9730423e-05, 9.9737685e-05, ..., 9.9730423e-05,
#          9.9730423e-05, 9.9730423e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner',
#   'word_probs': array([9.973102e-05, 9.973102e-05, 9.996631e-05, ..., 9.973102e-05,
#          9.973102e-05, 9.973102e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina',
#   'word_probs': array([9.973072e-05, 9.973043e-05, 9.973397e-05, ..., 9.973043e-05,
#          9.973043e-05, 9.973043e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral',
#   'word_probs': array([9.9816287e-05, 9.9816287e-05, 1.4787674e-04, ..., 9.9816287e-05,
#          9.9816287e-05, 9.9816287e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory',
#   'word_probs': array([9.9730401e-05, 9.9730401e-05, 2.7956038e-03, ..., 9.9730401e-05,
#          9.9730401e-05, 9.9730401e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another',
#   'word_probs': array([9.9730401e-05, 9.9730401e-05, 9.9732795e-05, ..., 9.9730401e-05,
#          9.9730401e-05, 9.9730401e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate',
#   'word_probs': array([9.973042e-05, 9.973042e-05, 9.973052e-05, ..., 9.973042e-05,
#          9.973042e-05, 9.973042e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap',
#   'word_probs': array([9.9730431e-05, 9.9730431e-05, 9.9730474e-05, ..., 9.9730431e-05,
#          9.9730431e-05, 9.9730431e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation',
#   'word_probs': array([9.9732322e-05, 9.9732322e-05, 1.0044788e-04, ..., 9.9732322e-05,
#          9.9732322e-05, 9.9732322e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F',
#   'word_probs': array([9.9730394e-05, 9.9730394e-05, 9.9730831e-05, ..., 9.9730394e-05,
#          9.9730394e-05, 9.9730394e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid',
#   'word_probs': array([9.9780314e-05, 9.9775745e-05, 1.1120942e-04, ..., 9.9775745e-05,
#          9.9775745e-05, 9.9775745e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist',
#   'word_probs': array([9.973046e-05, 9.973046e-05, 2.795325e-03, ..., 9.973046e-05,
#          9.973046e-05, 9.973046e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin',
#   'word_probs': array([9.9730794e-05, 9.9730627e-05, 9.9805999e-05, ..., 9.9730627e-05,
#          9.9730627e-05, 9.9730627e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church',
#   'word_probs': array([9.973041e-05, 9.973041e-05, 9.973104e-05, ..., 9.973041e-05,
#          9.973041e-05, 9.973041e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian',
#   'word_probs': array([9.973053e-05, 9.973053e-05, 9.977503e-05, ..., 9.973053e-05,
#          9.973053e-05, 9.973053e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended',
#   'word_probs': array([9.9731697e-05, 9.9731697e-05, 1.0020549e-04, ..., 9.9731697e-05,
#          9.9731697e-05, 9.9731697e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini',
#   'word_probs': array([9.989017e-05, 9.989017e-05, 2.619470e-04, ..., 9.989017e-05,
#          9.989017e-05, 9.989017e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon',
#   'word_probs': array([9.9730401e-05, 9.9730401e-05, 2.7956038e-03, ..., 9.9730401e-05,
#          9.9730401e-05, 9.9730401e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead',
#   'word_probs': array([9.9741039e-05, 9.9732308e-05, 2.7757748e-03, ..., 9.9732308e-05,
#          9.9732308e-05, 9.9732308e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered',
#   'word_probs': array([9.9797835e-05, 9.9797835e-05, 2.0876757e-03, ..., 9.9797835e-05,
#          9.9797835e-05, 9.9797835e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt',
#   'word_probs': array([9.9730416e-05, 9.9730416e-05, 2.7954150e-03, ..., 9.9730416e-05,
#          9.9730416e-05, 9.9730416e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette',
#   'word_probs': array([9.9730401e-05, 9.9730401e-05, 2.7956038e-03, ..., 9.9730401e-05,
#          9.9730401e-05, 9.9730401e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck',
#   'word_probs': array([9.9730467e-05, 9.9730467e-05, 2.7952914e-03, ..., 9.9730467e-05,
#          9.9730467e-05, 9.9730467e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami',
#   'word_probs': array([9.9730743e-05, 9.9730743e-05, 2.7920944e-03, ..., 9.9730743e-05,
#          9.9730743e-05, 9.9730743e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101',
#   'word_probs': array([9.9730401e-05, 9.9730401e-05, 2.7955885e-03, ..., 9.9730401e-05,
#          9.9730401e-05, 9.9730401e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha',
#   'word_probs': array([9.9730401e-05, 9.9730401e-05, 2.7956038e-03, ..., 9.9730401e-05,
#          9.9730401e-05, 9.9730401e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y',
#   'word_probs': array([9.9730401e-05, 9.9730401e-05, 2.7956038e-03, ..., 9.9730401e-05,
#          9.9730401e-05, 9.9730401e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap',
#   'word_probs': array([9.9731129e-05, 9.9731129e-05, 2.7881754e-03, ..., 9.9731129e-05,
#          9.9731129e-05, 9.9731129e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted',
#   'word_probs': array([9.9730401e-05, 9.9730401e-05, 2.7956038e-03, ..., 9.9730401e-05,
#          9.9730401e-05, 9.9730401e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period',
#   'word_probs': array([9.973052e-05, 9.973042e-05, 2.795544e-03, ..., 9.973042e-05,
#          9.973042e-05, 9.973042e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember',
#   'word_probs': array([9.9730394e-05, 9.9730394e-05, 9.9730809e-05, ..., 9.9730394e-05,
#          9.9730394e-05, 9.9730394e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil',
#   'word_probs': array([9.9730998e-05, 9.9730998e-05, 2.7896974e-03, ..., 9.9730998e-05,
#          9.9730998e-05, 9.9730998e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc',
#   'word_probs': array([9.9730401e-05, 9.9730401e-05, 2.7956038e-03, ..., 9.9730401e-05,
#          9.9730401e-05, 9.9730401e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think',
#   'word_probs': array([9.9841192e-05, 9.9841192e-05, 1.7303493e-04, ..., 9.9841192e-05,
#          9.9841192e-05, 9.9841192e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo',
#   'word_probs': array([9.9733435e-05, 9.9733414e-05, 2.7643919e-03, ..., 9.9733414e-05,
#          9.9733414e-05, 9.9733414e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes',
#   'word_probs': array([3.3174036e-04, 9.9938341e-05, 3.2580647e-04, ..., 9.9938341e-05,
#          9.9938341e-05, 9.9938341e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather',
#   'word_probs': array([9.973043e-05, 9.973040e-05, 2.795518e-03, ..., 9.973040e-05,
#          9.973040e-05, 9.973040e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle',
#   'word_probs': array([9.9730401e-05, 9.9730401e-05, 2.7956038e-03, ..., 9.9730401e-05,
#          9.9730401e-05, 9.9730401e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes',
#   'word_probs': array([9.973042e-05, 9.973042e-05, 9.973052e-05, ..., 9.973042e-05,
#          9.973042e-05, 9.973042e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases',
#   'word_probs': array([9.9730409e-05, 9.9730409e-05, 2.7956036e-03, ..., 9.9730409e-05,
#          9.9730409e-05, 9.9730409e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola',
#   'word_probs': array([9.9730445e-05, 9.9730445e-05, 2.7952089e-03, ..., 9.9730445e-05,
#          9.9730445e-05, 9.9730445e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock',
#   'word_probs': array([9.9738449e-05, 9.9738449e-05, 1.0280746e-04, ..., 9.9738449e-05,
#          9.9738449e-05, 9.9738449e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix',
#   'word_probs': array([9.9730431e-05, 9.9730431e-05, 2.7956017e-03, ..., 9.9730431e-05,
#          9.9730431e-05, 9.9730431e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew',
#   'word_probs': array([9.9730401e-05, 9.9730401e-05, 2.7956038e-03, ..., 9.9730401e-05,
#          9.9730401e-05, 9.9730401e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino',
#   'word_probs': array([9.9730431e-05, 9.9730409e-05, 2.7956036e-03, ..., 9.9730409e-05,
#          9.9730409e-05, 9.9730409e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti',
#   'word_probs': array([9.9730496e-05, 9.9730423e-05, 2.7956010e-03, ..., 9.9730423e-05,
#          9.9730423e-05, 9.9730423e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal',
#   'word_probs': array([9.9731318e-05, 9.9731318e-05, 2.7860445e-03, ..., 9.9731318e-05,
#          9.9731318e-05, 9.9731318e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal lacquered',
#   'word_probs': array([9.97323878e-05, 9.97323878e-05, 1.00049976e-04, ...,
#          9.97323878e-05, 9.97323878e-05, 9.97323878e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal lacquered concentrate',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal lacquered concentrate wingtips',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal lacquered concentrate wingtips container',
#   'word_probs': array([9.9735356e-05, 9.9735356e-05, 2.7443417e-03, ..., 9.9735356e-05,
#          9.9735356e-05, 9.9735356e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal lacquered concentrate wingtips container slice',
#   'word_probs': array([9.9730911e-05, 9.9730423e-05, 2.7955857e-03, ..., 9.9730423e-05,
#          9.9730423e-05, 9.9730423e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal lacquered concentrate wingtips container slice Rest',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal lacquered concentrate wingtips container slice Rest freekeh',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal lacquered concentrate wingtips container slice Rest freekeh adequate',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal lacquered concentrate wingtips container slice Rest freekeh adequate Fontina',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal lacquered concentrate wingtips container slice Rest freekeh adequate Fontina chunks—to',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal lacquered concentrate wingtips container slice Rest freekeh adequate Fontina chunks—to syrups',
#   'word_probs': array([9.973041e-05, 9.973041e-05, 9.973121e-05, ..., 9.973041e-05,
#          9.973041e-05, 9.973041e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal lacquered concentrate wingtips container slice Rest freekeh adequate Fontina chunks—to syrups Shank',
#   'word_probs': array([9.9734869e-05, 9.9734869e-05, 1.0142067e-04, ..., 9.9734869e-05,
#          9.9734869e-05, 9.9734869e-05], dtype=float32)},
#  {'prompt': 'recipe for grilled apple apéritif Spanish North cellophane tostada Sushi Shrimp Omelet prickly pounding jícama aerates collects Crumbs seep winery coats Ball Need farmer dente scrub Pilsner Argentina mineral Savory when Another concentrate Overlap Saute preparation 105°F peats canning 28 caraway rancid twist begin church Alsatian themselves Crisp Blended cannellini capon Instead layered mitt drumette littleneck pastrami 101 mocha y snap reconstituted period Remember boil Bosc Ale candied red rather think peels coral Jumbo Cubes Gather Straddle 15minutes creases Pizzaiola ziplock overmix brew Cioppino rösti varietal lacquered concentrate wingtips container slice Rest freekeh adequate Fontina chunks—to syrups Shank overblend',
#   'word_probs': array([9.97304e-05, 9.97304e-05, 9.97304e-05, ..., 9.97304e-05,
#          9.97304e-05, 9.97304e-05], dtype=float32)}]

# %%
index_to_word.get(1)
# Out:
# '<unk>'
